# %%
# %matplotlib inline
import os, glob, sys
import pandas as pd
import numpy as np
import datetime as dt
from math import sqrt
from collections import Counter

# %%
data_files = glob.glob(os.path.join('.','data\competition_data','comp_*'))
newtrain_df = pd.read_csv(os.path.join('.','data\competition_data','train1.csv'))
                    
#for file_name in data_files:
#    print os.path.split(file_name)[-1]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-cf1c28595d80> in <module>()
#       1 data_files = glob.glob(os.path.join('.','data\competition_data','comp_*'))
# ----> 2 newtrain_df = pd.read_csv(os.path.join('.','data\competition_data','train1.csv'))
#       3
#       4 #for file_name in data_files:
#       5 #    print os.path.split(file_name)[-1]
#
# ...

# %%
component_id_1 = newtrain_df['component_id_1']
weightcomp = []
for key in component_id_1:
    print key
    for file_name in data_files:
        #print file_name
        comp_df = pd.read_csv(os.path.join('..','competition_data',file_name),header=0, index_col=0)
    #print comp_df['component_id']
    #print comp_df[0:10]
        if key in comp_df.index:
            weightcomp.append (comp_df.loc[key]['weight'])
    #break
# Out:
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1624
# C-1624
# C-1624
# C-1624
# C-1624
# C-1624
# C-1624
# C-1624
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1622
# C-1622
# C-1622
# C-1622
# C-1622
# C-1622
# C-1622
# C-1622
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-0823
# C-1536
# C-1536
# C-1536
# C-1536
# C-1536
# C-1536
# C-1536
# C-1536
# C-1623
# C-1623
# C-1623
# C-1623
# C-1623
# C-1623
# C-1623
# C-1623
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# C-1312
# ...

# %%
weightcomp[0:10]
# Out:
# [0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005,
#  0.052000000000000005]
